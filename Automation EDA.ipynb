# %% [markdown]
# <b>dtale</b>

# %%
# !pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\users\harsha\anaconda3\anaconda\lib\site-packages (3.17.0)
# Requirement already satisfied: dash-daq<=0.5.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: future>=0.14.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (1.0.0)
# Requirement already satisfied: missingno in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (0.5.2)
# Requirement already satisfied: pandas in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (2.2.2)
# Requirement already satisfied: squarify in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (0.4.4)
# Requirement already satisfied: strsimpy in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: six in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: xlrd in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (2.0.2)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (2024.8.30)
# Requirement already satisfied: dash-bootstrap-components<=1.7.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (1.7.1)
# Requirement already satisfied: lz4 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (4.3.2)
# Requirement already satisfied: cycler in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (0.11.0)
# Requirement already satisfied: dash<=2.18.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (2.18.2)
# Requirement already satisfied: seaborn in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (0.13.2)
# Requirement already satisfied: werkzeug in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (3.0.3)
# Requirement already satisfied: Flask-Compress in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (1.17)
# Requirement already satisfied: scikit-learn in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (1.5.1)
# Requirement already satisfied: statsmodels in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (0.14.2)
# Requirement already satisfied: networkx in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (3.3)
# Requirement already satisfied: numpy in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (1.26.4)
# Requirement already satisfied: openpyxl!=3.2.0b1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (3.1.5)
# Requirement already satisfied: xarray in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (2023.6.0)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (1.13.1)
# Requirement already satisfied: et-xmlfile in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: plotly in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (5.24.1)
# Requirement already satisfied: Flask in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (3.0.3)
# Requirement already satisfied: itsdangerous in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (2.2.0)
# Requirement already satisfied: requests in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (2.32.3)
# Requirement already satisfied: kaleido in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (1.0.0)
# Requirement already satisfied: matplotlib in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dtale) (3.9.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.5)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dash<=2.18.2->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dash<=2.18.2->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dash<=2.18.2->dtale) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dash<=2.18.2->dtale) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dash<=2.18.2->dtale) (4.14.0)
# Requirement already satisfied: retrying in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dash<=2.18.2->dtale) (1.4.0)
# Requirement already satisfied: nest-asyncio in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dash<=2.18.2->dtale) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from dash<=2.18.2->dtale) (75.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from Flask->dtale) (3.1.4)
# Requirement already satisfied: click>=8.1.3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from Flask->dtale) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from Flask->dtale) (1.6.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from plotly->dtale) (8.2.3)
# Requirement already satisfied: packaging in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from plotly->dtale) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from werkzeug->dtale) (2.1.3)
# Requirement already satisfied: brotli in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: zstandard in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from Flask-Compress->dtale) (0.23.0)
# Requirement already satisfied: choreographer>=1.0.5 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from kaleido->dtale) (1.0.9)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from kaleido->dtale) (1.1.0)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from kaleido->dtale) (3.10.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas->dtale) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas->dtale) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->dtale) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->dtale) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->dtale) (2.2.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from scikit-learn->dtale) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from scikit-learn->dtale) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from statsmodels->dtale) (0.5.6)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from choreographer>=1.0.5->kaleido->dtale) (3.20.1)
# Requirement already satisfied: colorama in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from click>=8.1.3->Flask->dtale) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from importlib-metadata->dash<=2.18.2->dtale) (3.17.0)

# %%
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
import dtale
dtale.show(df)
# Out:
# C:\Users\Harsha\anaconda3\anaconda\Lib\site-packages\kaleido\__init__.py:14: UserWarning:
#
#
#
# Warning: You have Plotly version 5.24.1, which is not compatible with this version of Kaleido (1.0.0).
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-IP3R72GF:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <b>Pandas profiling or y data profiling

# %%
pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\harsha\anaconda3\anaconda\lib\site-packages (4.16.1)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (3.1.4)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (0.14.2)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.7.0)
# Requirement already satisfied: pillow in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pydantic>=2->ydata-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pydantic>=2->ydata-profiling) (4.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2024.8.30)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: colorama in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: puremagic in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.29)
# Requirement already satisfied: six in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
df1=sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pip install jupyterlab_widgets
# Out:
# Requirement already satisfied: jupyterlab_widgets in c:\users\harsha\anaconda3\anaconda\lib\site-packages (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df1, explorative=True)
profile.to_file('output.html')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 84.73it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# <b>Sweetviz

# %%
# !pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\harsha\anaconda3\anaconda\lib\site-packages (2.3.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from sweetviz) (1.26.4)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from sweetviz) (3.9.2)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from sweetviz) (4.66.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from sweetviz) (1.13.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from sweetviz) (3.1.4)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from sweetviz) (6.5.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3)
# Requirement already satisfied: colorama in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)

# %%
import sweetviz as sv
report=sv.analyze(df)
report.show_html("sweet_report.html")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweet_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# <b>Autoviz

# %%
# !pip install git+git://github.com/AutoViML/AutoViz.git
# !pip install xlrd
# Out:
# Collecting git+git://github.com/AutoViML/AutoViz.git
#   Cloning git://github.com/AutoViML/AutoViz.git to c:\users\harsha\appdata\local\temp\pip-req-build-zru7ko77
#   ERROR: Error [WinError 2] The system cannot find the file specified while executing command git version
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?
# Requirement already satisfied: xlrd in c:\users\harsha\anaconda3\anaconda\lib\site-packages (2.0.2)

# %%
import datetime as dt
import pandas as pd

# %%
# Start of AutoViz process
start_time = dt.datetime.now()
print("Started at ", start_time)
# Out:
# Started at  2025-06-27 10:08:54.834490

# %%
import pandas as pd
df = pd.read_csv('DressSales.csv')
df.head()
# Out:
#      Dress_ID  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0  1006032852       2114       2274      2491      2660      2727      2887
# 1  1212192089        151        275       570       750       813      1066
# 2  1190380701          6          7         7         7         8         8
# 3   966005983       1005       1128      1326      1455      1507      1621
# 4   876339541        996       1175      1304      1396      1432      1559
#
#    10/9/2013 12/9/2013 14/9/2013  ... Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0       2930      3119      3204  ...         NaN         NaN         NaN
# 1       1164      1558      1756  ...         NaN         NaN         NaN
# 2          9        10        10  ...         NaN         NaN         NaN
# 3       1637      1723      1746  ...         NaN         NaN         NaN
# 4       1570      1638      1655  ...         NaN         NaN         NaN
#
#   Unnamed: 29  Unnamed: 30  Unnamed: 31  Unnamed: 32  Unnamed: 33  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN          NaN
# 4         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 34  Unnamed: 35
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 36 columns]

# %%
# !pip install autoviz
# Out:
# Requirement already satisfied: autoviz in c:\users\harsha\anaconda3\anaconda\lib\site-packages (0.1.905)
# Requirement already satisfied: xlrd in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (2.0.2)
# Requirement already satisfied: wordcloud in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.9.4)
# Requirement already satisfied: emoji in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (2.14.1)
# Requirement already satisfied: pyamg in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (5.2.1)
# Requirement already satisfied: scikit-learn in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.5.1)
# Requirement already satisfied: statsmodels in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (0.14.2)
# Requirement already satisfied: nltk in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (0.19.0)
# Requirement already satisfied: xgboost<1.7,>=0.82 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.6.2)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (4.14.0)
# Requirement already satisfied: pandas-dq>=1.29 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.29)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.26.4)
# Requirement already satisfied: hvplot>=0.9.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (0.11.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.19.1)
# Requirement already satisfied: panel>=1.4.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.5.2)
# Requirement already satisfied: pandas>=2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (2.2.2)
# Requirement already satisfied: matplotlib>3.7.4 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (3.9.2)
# Requirement already satisfied: seaborn>0.12.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: bokeh>=3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.6.0)
# Requirement already satisfied: colorcet in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (24.1)
# Requirement already satisfied: param<3.0,>=2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (2.1.1)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas>=2.0->autoviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas>=2.0->autoviz) (2023.3)
# Requirement already satisfied: bleach in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (4.1.0)
# Requirement already satisfied: linkify-it-py in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (2.0.0)
# Requirement already satisfied: markdown in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (0.3.0)
# Requirement already satisfied: requests in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (4.66.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from scikit-learn->autoviz) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from scikit-learn->autoviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from scikit-learn->autoviz) (3.5.0)
# Requirement already satisfied: click in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from nltk->autoviz) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from nltk->autoviz) (2024.9.11)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from statsmodels->autoviz) (0.5.6)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2022.9.0)
# Requirement already satisfied: six in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from patsy>=0.5.6->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: colorama in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from click->nltk->autoviz) (0.4.6)
# Requirement already satisfied: uc-micro-py in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (2.1.3)

# %%
pip install autoviz --upgrade
# Out:
# Requirement already satisfied: autoviz in c:\users\harsha\anaconda3\anaconda\lib\site-packages (0.1.905)
# Requirement already satisfied: xlrd in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (2.0.2)
# Requirement already satisfied: wordcloud in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.9.4)
# Requirement already satisfied: emoji in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (2.14.1)
# Requirement already satisfied: pyamg in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (5.2.1)
# Requirement already satisfied: scikit-learn in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.5.1)
# Requirement already satisfied: statsmodels in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (0.14.2)
# Requirement already satisfied: nltk in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (3.9.1)
# Requirement already satisfied: textblob in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (0.19.0)
# Requirement already satisfied: xgboost<1.7,>=0.82 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.6.2)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (2024.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (4.14.0)
# Requirement already satisfied: pandas-dq>=1.29 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.29)
# Requirement already satisfied: numpy>=1.24.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.26.4)
# Requirement already satisfied: hvplot>=0.9.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (0.11.0)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.19.1)
# Requirement already satisfied: panel>=1.4.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (1.5.2)
# Requirement already satisfied: pandas>=2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (2.2.2)
# Requirement already satisfied: matplotlib>3.7.4 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (3.9.2)
# Requirement already satisfied: seaborn>0.12.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: bokeh>=3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.6.0)
# Requirement already satisfied: colorcet in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.1.0)
# Requirement already satisfied: packaging in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (24.1)
# Requirement already satisfied: param<3.0,>=2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (2.1.1)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from holoviews>=1.16.0->autoviz) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from matplotlib>3.7.4->autoviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas>=2.0->autoviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from pandas>=2.0->autoviz) (2023.3)
# Requirement already satisfied: bleach in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (4.1.0)
# Requirement already satisfied: linkify-it-py in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (2.0.0)
# Requirement already satisfied: markdown in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (0.3.0)
# Requirement already satisfied: requests in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from panel>=1.4.0->autoviz) (4.66.5)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from scikit-learn->autoviz) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from scikit-learn->autoviz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from scikit-learn->autoviz) (3.5.0)
# Requirement already satisfied: click in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from nltk->autoviz) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from nltk->autoviz) (2024.9.11)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from statsmodels->autoviz) (0.5.6)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bokeh>=3.1->holoviews>=1.16.0->autoviz) (2022.9.0)
# Requirement already satisfied: six in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from patsy>=0.5.6->statsmodels->autoviz) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from bleach->panel>=1.4.0->autoviz) (0.5.1)
# Requirement already satisfied: colorama in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from click->nltk->autoviz) (0.4.6)
# Requirement already satisfied: uc-micro-py in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from linkify-it-py->panel>=1.4.0->autoviz) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from markdown-it-py->panel>=1.4.0->autoviz) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->panel>=1.4.0->autoviz) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from requests->panel>=1.4.0->autoviz) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harsha\anaconda3\anaconda\lib\site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews>=1.16.0->autoviz) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from autoviz.AutoViz_Class import AutoViz_Class

AV = AutoViz_Class()
dftc = AV.AutoViz(
    filename=None, 
    sep=',' , 
    depVar='Class', 
    dfte=df, 
    header=0, 
    verbose=1, 
    lowess=False, 
    chart_format='png', 
    max_rows_analyzed=300000, 
    max_cols_analyzed=30
)
# Out:
# Shape of your Data Set loaded: (500, 36)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  6
#     Number of Integer-Categorical Columns =  12
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  6
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  12
#     36 Predictors classified...
#         12 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35']
# Could not find given target var in data set. Please check input
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 from autoviz.AutoViz_Class import AutoViz_Class
#       3 AV = AutoViz_Class()
# ----> 4 dftc = AV.AutoViz(
#       5     filename=None,
#       6     sep=',' ,
#       7     depVar='Class',
#       8     dfte=df,
#       9     header=0,
#      10     verbose=1,
#      11     lowess=False,
#      12     chart_format='png',
#      13     max_rows_analyzed=300000,
#      14     max_cols_analyzed=30
#      15 )
#
# File ~\anaconda3\anaconda\Lib\site-packages\autoviz\AutoViz_Class.py:239, in AutoViz_Class.AutoViz(self, filename, sep, depVar, dfte, header, verbose, lowess, chart_format, max_rows_analyzed, max_cols_analyzed, save_plot_dir)
#     235     dft = AutoViz_Holo(filename, sep, dep_var, header, verbose,
#     236                        lowess, chart_format, max_rows_analyzed,
#     237                        max_cols_analyzed, save_plot_dir)
#     238 else:
# --> 239     dft = self.AutoViz_Main(filename, sep, dep_var, header, verbose,
#     240                             lowess, chart_format, max_rows_analyzed,
#     241                             max_cols_analyzed, save_plot_dir)
#     242 return dft
#
# File ~\anaconda3\anaconda\Lib\site-packages\autoviz\AutoViz_Class.py:274, in AutoViz_Class.AutoViz_Main(self, filename, sep, dep_var, header, verbose, lowess, chart_format, max_rows_analyzed, max_cols_analyzed, save_plot_dir)
#     271 ############   Start the clock here and classify variables in data set first ########
#     272 start_time = time.time()
# --> 274 (dft, dep_var, id_cols, bool_vars, cats, continuous_vars, discrete_string_vars, date_vars, classes,
#     275  problem_type, selected_cols) = classify_print_vars(filename, sep, max_rows_analyzed, max_cols_analyzed,
#     276                                                     dep_var, header, verbose)
#     278 ###########  This is where perform data quality checks on data ################
#     279 if verbose >= 1:
#
# ValueError: not enough values to unpack (expected 11, got 8)

# %%
import autoviz
print(autoviz.__version__)
# Out:
# 0.1.905
